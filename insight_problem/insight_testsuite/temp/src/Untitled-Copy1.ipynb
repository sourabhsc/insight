# %%
############### USE LAMBDA ###########
import os
from collections import OrderedDict
import math


def sorting(property, dict_all, nrows):

    unique_key = list(set(dict_all[property]))
    unique_key = sorted(unique_key)
    counter = [0] * len(unique_key)
    for j in range(len(unique_key)):
        for i in range(nrows):
            if unique_key[j] == dict_all[property][i]:
                counter[j] = counter[j] + 1
    return unique_key, counter


if __name__ == '__main__':

    DIR = os.getcwd()
    with open(DIR + '/../insight_testsuite/tests/tests_1/input/h1b_input.csv') as fp:
        for ii, line in enumerate(iter(fp.readline, '')):
            if ii == 0:
                keys = line.split(';')
                dict_all = OrderedDict.fromkeys(keys)
                for key in keys:
                    dict_all[key] = []
            else:
                [dict_all[keys[j]].append(line.split(';')[j]) for j in range(len(keys))]
    # print (ii)
    # lines.append(line)
    import pandas as pd
    df = pd.DataFrame(dict_all)
    display(df)
    '''
    keys = lines[0].split(';')
    print (len(keys), len(lines))
    dict_all = OrderedDict.fromkeys(keys)
    for key in keys:
        dict_all[key] = []
    [dict_all[keys[j]].append(lines[ii].split(';')[j]) for ii in range(1, len(lines)) for j in range(len(keys))]
    '''
    occupation_keys = ['TOP_OCCUPATIONS',
                       'NUMBER_CERTIFIED_APPLICATIONS', 'PERCENTAGE']
    states_keys = ['TOP_STATES', 'NUMBER_CERTIFIED_APPLICATIONS', 'PERCENTAGE']

    nrows = len(dict_all[''])
    unique_key, counter = sorting("SOC_NAME", dict_all, nrows)
    print (counter)
    unique_key, counter = sorting("WORKSITE_STATE", dict_all, nrows)
    print (counter)
# Out:
#              CASE_NUMBER CASE_STATUS CASE_SUBMITTED DECISION_DATE  \
# 0  0  I-200-18026-338377   CERTIFIED     2018-01-29    2018-02-02
# 1  1  I-200-17296-353451   CERTIFIED     2017-10-23    2017-10-27
# 2  2  I-200-18242-524477   CERTIFIED     2018-08-30    2018-09-06
# 3  3  I-200-18070-575236   CERTIFIED                   2018-03-30
# 4  4  I-200-18243-850522   CERTIFIED     2018-08-31    2018-09-07
# 5  5  I-200-18142-939501   CERTIFIED     2018-05-22    2018-05-29
# 6  6  I-200-18121-552858   CERTIFIED     2018-05-01    2018-05-07
# 7  7  I-200-18215-849606   CERTIFIED     2018-08-03    2018-08-09
# 8  8  I-201-17339-472823   CERTIFIED     2017-12-08    2017-12-14
# 9  9  I-200-18233-239931   CERTIFIED     2018-08-21    2018-08-27
#
#     VISA_CLASS EMPLOYMENT_START_DATE EMPLOYMENT_END_DATE  \
# 0         H-1B            2018-07-28          2021-07-27
# 1         H-1B            2017-11-06          2020-11-06
# 2         H-1B            2018-09-10          2021-09-09
# ...
